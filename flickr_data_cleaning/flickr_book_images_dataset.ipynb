# %%
import pandas as pd
import numpy as np
from pandas.api.types import is_numeric_dtype

# %%
#read the file from local
df0=pd.read_csv('/Users/mohammadkhan/Desktop/Data Quality Engineer Data File - BL-Flickr-Images-Book.csv',encoding='utf-8')

# %%
#Check for the existing column names
df0.columns
# Out:
# Index(['Identifier', 'Edition Statement', 'Place of Publication',
#        'Date of Publication', 'Publisher', 'Title', 'Author', 'Contributors',
#        'Corporate Author', 'Corporate Contributors', 'Former owner',
#        'Engraver', 'Issuance type', 'Flickr URL', 'Shelfmarks'],
#       dtype='object')

# %%
#Drop the columns as mentioned in the readme doc
df0.drop(['Edition Statement','Corporate Author','Corporate Contributors',
'Former owner','Engraver','Contributors','Issuance type','Shelfmarks'], axis=1, inplace=True)

# %%
#Setting the Index for the df0 as per readme doc
df0.set_index('Identifier', inplace=True)

# %%
#Check if the Index is Unique
df0.index.is_unique
# Out:
# True

# %% [markdown]
# ### Label based Indexing (loc[ ])  vs  Position based Indexing (iloc[ ]) for pandas dataframes

# %% [markdown]
# #### Selecting column by label

# %%
df0.loc[:,'Publisher'].tail(10)
# Out:
# Identifier
# 4117751          John Wiley & Sons
# 4117752             Trübner & Co.
# 4156359        G. P. Putnam's Sons
# 4157746     F. C. and J. Rivington
# 4157862                 T. Fordyce
# 4158088                        NaN
# 4158128            M. Mozley & Son
# 4159563    T. Cadell and W. Davies
# 4159587           Mackenzie & Dent
# 4160339                        NaN
# Name: Publisher, dtype: object

# %% [markdown]
# #### Selecting Column by Index (Position)

# %%
df0.iloc[:,2].tail(10)
# Out:
# Identifier
# 4117751          John Wiley & Sons
# 4117752             Trübner & Co.
# 4156359        G. P. Putnam's Sons
# 4157746     F. C. and J. Rivington
# 4157862                 T. Fordyce
# 4158088                        NaN
# 4158128            M. Mozley & Son
# 4159563    T. Cadell and W. Davies
# 4159587           Mackenzie & Dent
# 4160339                        NaN
# Name: Publisher, dtype: object

# %% [markdown]
# #### Selecting row by label

# %%
df0.loc[667]
# Out:
# Place of Publication                  pp. 40. G. Bryan & Co: Oxford, 1898
# Date of Publication                                                   NaN
# Publisher                                                             NaN
# Title                   The Coming of Spring, and other poems. By J. A...
# Author                                                      A., J.|A., J.
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 667, dtype: object

# %% [markdown]
# #### Selecting row by lndex (Position)

# %%
df0.iloc[7]

# %% [markdown]
# #### Selecting rows based on label slices

# %%
df0.loc[[874,2956,3131],'Place of Publication':'Publisher']

# %% [markdown]
# #### Selecting rows based on lndex slices

# %%
df0.iloc[[8,16,19],0:3]

# %%
# Checking for null values in Date of Publication Column
df0['Date of Publication'].isnull().sum()
# Out:
# 181

# %%
#Checking for Null Values in Date of Publication Column
df0[df0['Date of Publication'].isnull()]
# Out:
#                                          Place of Publication  \
# Identifier
# 667                       pp. 40. G. Bryan & Co: Oxford, 1898
# 11852                      pp. 40. W. Cann: Plymouth, [1876?]
# 55031                    pp. vi. 216. Hatchards: London, 1888
# 124885                     pp. 64. W. Cann: Plymouth, [1870?]
# 156798                pp. 95. Erskine Macdonald: London, 1921
# 157633           pp. xi. 59. J. Parker & Co.: Oxford, [1900.]
# 259933             pp. xii. 59. Thomas Burleigh: London, 1900
# 284576                                        Москва, 1857-60
# 355309                    pp. 92. Heath Cranton: London, 1919
# 367760                  pp. x. 429. John Murray: London, 1894
# 381198            2 vol. W. Blackwood & Sons: Edinburgh, 1888
# 529537             pp. 31. S. Harper & Sons: Barnstaple, 1899
# 727848                    pp. 281. Hatchards: London, [1889.]
# 804446                pp. 128. R. Aickin & Co.: Belfast, 1896
# 811126                  pp. 64. W. & J. Kennedy: Hawick, 1899
# 848161      pp. 359. Thomas Nelson & Sons: London, 1889 [1...
# 856091      pp. 349. Griffith, Farran, Okeden & Welsh: Lon...
# 907096                     pp. 59. Blackwell: Oxford, [1919.]
# 911866             pp. 110. John Lane: London, New York, 1918
# 930213         pp. 221. George Routledge & Sons: London, 1887
# 954240                                  pp. 152. Москва, 1898
# 959759                    2 Thle. Frankfurt am Main, 1880, 8º
# 979058                                  Санктпетербургъ, 1867
# 980873             pp. vi. 250. W. Blackwood: Edinburgh, 1889
# 994020      pp. 332. Hurst & Blackett: London; Bolton [pri...
# 1024863             pp. vi. 344. Chapman & Hall: London, 1887
# 1179671                  2 vol. Chatto & Windus: London, 1888
# 1197533     pp. 20. [Appledore Press: New-Haven, Conn.,] 1875
# 1229458        pp. 229. G. N. Morang & Company: Toronto, 1900
# 1246734                                 Санктпетербургъ, 1845
# ...                                                       ...
# 3619288                pp. xii. 139. F. Rodda: Penzance, 1895
# 3626183        pp. xx. 372. William P. Nimmo: Edinburgh, 1868
# 3631247      pp. vi. 209. Blackwood and Sons: Edinburgh, 1888
# 3631248     pp. x. 228. W. Blackwood & Sons: Edinburgh and...
# 3641137                       pp. 60. Privately printed, 1876
# 3691484                    pp. 14. W. Cann: Plymouth, [1876?]
# 3705638               pp. x. 283. Methuen & Co.: London, 1900
# 3705707               George G. Harrap & Co.: London, [1913.]
# 3761232                              pp. xi. 273. Вятка, 1870
# 3763128                                                1885?]
# 3775658                2 vol. F. V. White & Co.: London, 1888
# 3779191               pp. 87. William Heinemann: London, 1917
# 3806535               pp. 59. Atlas Press: Melbourne, [1900?]
# 3813751                                 Санктпетербургъ, 1873
# 3865542                       pp. 50. John Lane: London, 1896
# 3893909               pp. ii. 80. A. W. Dawson: Newport, 1898
# 3926780          Leeds: Bean & Son; Leamington: Hamblen, 1883
# 3952291                      pp. 77. E. Mathews: London, 1897
# 3993182       ff. 29. M. Ward & Co.: London and Belfast, 1895
# 3995356                              pp. 215. въ Москвѣ, 1889
# 4018987                                          Москва, 1860
# 4024911                   3 vol. Chapman & Hall: London, 1864
# 4046468                            London: Elliot Stock, 1897
# 4053464                       London: E. Nutt; E. Cooke, 1733
# 4072044                   London: D. Wilson & T. Durham, 1752
# 4077038           London: printed for Nicholas Vavasour, 1634
# 4112297            London: Macmillan & Co., pp. xl, 400. 1895
# 4113816     pp. xxvi, 375. London: Jackson, Walford & Hodd...
# 4114334                pp. viii. 64. J. Debrett: London, 1789
# 4115138                                  G. Eld: London, 1608
#
#            Date of Publication Publisher  \
# Identifier
# 667                        NaN       NaN
# 11852                      NaN       NaN
# 55031                      NaN       NaN
# 124885                     NaN       NaN
# 156798                     NaN       NaN
# 157633                     NaN       NaN
# 259933                     NaN       NaN
# 284576                     NaN       NaN
# 355309                     NaN       NaN
# 367760                     NaN       NaN
# 381198                     NaN       NaN
# 529537                     NaN       NaN
# 727848                     NaN       NaN
# 804446                     NaN       NaN
# 811126                     NaN       NaN
# 848161                     NaN       NaN
# 856091                     NaN       NaN
# 907096                     NaN       NaN
# 911866                     NaN       NaN
# 930213                     NaN       NaN
# 954240                     NaN       NaN
# 959759                     NaN       NaN
# 979058                     NaN       NaN
# 980873                     NaN       NaN
# 994020                     NaN       NaN
# 1024863                    NaN       NaN
# 1179671                    NaN       NaN
# 1197533                    NaN       NaN
# 1229458                    NaN       NaN
# 1246734                    NaN       NaN
# ...                        ...       ...
# 3619288                    NaN       NaN
# 3626183                    NaN       NaN
# 3631247                    NaN       NaN
# 3631248                    NaN       NaN
# 3641137                    NaN       NaN
# 3691484                    NaN       NaN
# 3705638                    NaN       NaN
# 3705707                    NaN       NaN
# 3761232                    NaN       NaN
# 3763128                    NaN       NaN
# 3775658                    NaN       NaN
# 3779191                    NaN       NaN
# 3806535                    NaN       NaN
# 3813751                    NaN       NaN
# 3865542                    NaN       NaN
# 3893909                    NaN       NaN
# 3926780                    NaN       NaN
# 3952291                    NaN       NaN
# 3993182                    NaN       NaN
# 3995356                    NaN       NaN
# 4018987                    NaN       NaN
# 4024911                    NaN       NaN
# 4046468                    NaN       NaN
# 4053464                    NaN       NaN
# 4072044                    NaN       NaN
# 4077038                    NaN       NaN
# 4112297                    NaN       NaN
# 4113816                    NaN       NaN
# 4114334                    NaN       NaN
# 4115138                    NaN       NaN
#
#                                                         Title  \
# Identifier
# 667         The Coming of Spring, and other poems. By J. A...
# 11852       A Question of Holy Writ, suggested by a lectur...
# 55031       The White Man's Foot ... With ... illustration...
# 124885      The Divine Artisan ... A poem. [By Joseph Plim...
# 156798      Reflections. [Verses.] By A. M. B. [i.e. A. M....
# 157633      The Battle of Maldon, and other renderings fro...
# 259933      The Taking of the Flag, and other recitations,...
# 284576      Дневникъ Каммеръ-Юнкера Берхгольца, веденный и...
# 355309      The City of Renown, and other poems. By C. and...
# 367760      Songs, Poems, & Verses. By Helen, Lady Dufferi...
# 381198      Lady Bluebeard. By the author of 'Zit and Xoe'...
# 529537      A Bundle of Sonnets. Based on the Italian mode...
# 727848      Under a Cloud. By the author of “The Atelier d...
# 804446      Sung by Six. [Poems by] S. K. Cowan, J. H. Cou...
# 811126      In Borderland. Border and other verses ... Wit...
# 848161      Pincherton Farm. The story of Maurice Hamilton...
# 856091      [The White Elephant; or, the Hunters of Ava an...
# 907096      Zoar. A book of verse by Helen & Bernard Bosan...
# 911866      [There is no Death. Poems ... With a foreword ...
# 930213      David & Bathsheba. A royal romance based on ra...
# 954240      Пугачевщина въ Сибири. Очеркъ по документамъ э...
# 959759      Lehrbuch der Geschichte der alten Welt, mit be...
# 979058      Очерки Авсрто-Прусской войны въ 1866 году, съ ...
# 980873      A Dreamer of Dreams. A modern romance. By the ...
# 994020      The Duchess. A story. By the author of “Molly ...
# 1024863     I. D. B. (Illicit Diamond Buying), or the Adve...
# 1179671     Eve. A novel. By the author of “John Herring,”...
# 1197533          Famine: a masque. [By William James Linton.]
# 1229458     Lullaby-Land. Songs of Childhood ... Selected ...
# 1246734     Записки Дюка Лирійскаго и Бервикскаго во время...
# ...                                                       ...
# 3619288     Randigal Rhymes and a glossary of Cornish Word...
# 3626183     [The Poetical Works of James Thomson, James Be...
# 3631247               Thoth. A romance. [By J. S. Nicholson.]
# 3631248             [Thoth. A romance. [By J. S. Nicholson.]]
# 3641137     Floating Spars. [Verses. With a memoir of the ...
# 3691484     The Turkish Atrocities. [In verse. By Joseph P...
# 3705638     The Rubaiyat of Omar Khayyam. Translated by E....
# 3705707     Rubáiyát of Omar Khayyám. Presented by Will...
# 3761232     Исторія Вятскаго края съ древнихъ временъ до н...
# 3763128     The Marquise de Vaudreuil. [A play, by Jemima ...
# 3775658     The Honble Mrs. Vereker.-A novel. By the autho...
# 3779191     War Poems, and other verses ... With an introd...
# 3806535     The King's Folly and the Queen's Revenge. The ...
# 3813751     Генералъ Фрейтагъ и его боевые товарищы. Три э...
# 3865542     The Purple East. A series of sonnets on Englan...
# 3893909     West Ward Rhymes, and other verses. By “The Me...
# 3926780     [A solitary evening reverie at home. In memori...
# 3952291     Lays and Legends of the Weald of Kent ... With...
# 3993182     Senilia 1891-1894. [Poems, chiefly in Latin.] ...
# 3995356     Сочиненія Князя Курбскаго, какъ историческій м...
# 4018987     Подлинныя бумаги до бунта Пугачова относящіяся...
# 4024911     Zoe's 'Brand.' By the author of “Recommended t...
# 4046468     Hugo of Avendon. In four acts. By E. L. M. [i....
# 4053464     A friendly epistle [by Joseph Mitchell?] to th...
# 4072044     The scale: or, Woman weighed with man. A poem ...
# 4077038     The noble souldier. Or, A contract broken, jus...
# 4112297     Japhet in search of a Father ... With an intro...
# 4113816     The lacemakers: sketches of Irish characters w...
# 4114334     The Sword of Peace; or, a voyage of love; a co...
# 4115138     The Revenger's Tagaedie. As it hath beene sund...
#
#                                                        Author  \
# Identifier
# 667                                             A., J.|A., J.
# 11852                                   ACKLAND - Lieut., R.N
# 55031                                            Allen, Grant
# 124885                                                    NaN
# 156798                                              B., A. M.
# 157633                                           B., F. W. L.
# 259933                          BELL, Henry Thomas Mackenzie.
# 284576                        Bergholz, Friedrich Wilhelm von
# 355309             BIRCH, afterwards SALWEY, Charlotte Maria.
# 367760      BLACKWOOD, Helen Selina - Baroness Dufferin, a...
# 381198                                                    NaN
# 529537                                  BUNDLE, Jacob - pseud
# 727848                                                    NaN
# 804446                                 COWAN, Samuel Kennedy.
# 811126                           CRAIG, Matthew Robert Smith.
# 848161                              E. A. B. D. (E. A. Bland)
# 856091       DALTON, William - Writer of Stories for Children
# 907096                    DENDY, afterwards BOSANQUET, Helen.
# 911866                            DENNYS, Richard Molesworth.
# 930213                    DICK, Conzae - and CRESWELL (James)
# 954240       DMITRIEV-MAMONOV, Aleksandr Ippolitovich - Count
# 959759                                       DOERING, Emylie.
# 979058      DRAGOMIROV, Mikhail Ivanovich.|DRAGOMIROV, Mik...
# 980873                                                    NaN
# 994020                                                    NaN
# 1024863                                             E., W. T.
# 1179671                                                   NaN
# 1197533                                                   NaN
# 1229458                                        FIELD, Eugene.
# 1246734     FITZ-JAMES, James Francis - Duke of Berwick an...
# ...                                                       ...
# 3619288               THOMAS, Joseph - of St. Michael's Mount
# 3626183                                        Thomson, James
# 3631247                                                   NaN
# 3631248                                                   NaN
# 3641137                             TINDALE, Thomas Plumpton.
# 3691484                                                   NaN
# 3705638                                                   NaN
# 3705707                                                   NaN
# 3761232     VASIL'EV, S. - of Vyatka and BEKHTEREV (Nikola...
# 3763128                                                   NaN
# 3775658                                                   NaN
# 3779191                              VERNÈDE, Robert Ernest.
# 3806535                                                   NaN
# 3813751                               VOLOTSKOI, Aleksandr A.
# 3865542                           WATSON, William - Sir, Poet
# 3893909                                                   NaN
# 3926780                WILKINSON, Edward - Rector of Snargate
# 3952291                                       WINSER, Lilian.
# 3993182                                             Y., W. S.
# 3995356                             YASINSKY, Anton Nikitich.
# 4018987                        ZHELEZNOV, Ioasaf Ignat'evich.
# 4024911                                                   NaN
# 4046468                                          DAY, Walter.
# 4053464                                                   NaN
# 4072044                                      MONCREIFF, John.
# 4077038                            ROWLEY, Samuel - Dramatist
# 4112297                                    Marryat, Frederick
# 4113816              MEREDITH, Susanna.|WIBERG, Carl Fredrik.
# 4114334                                                   NaN
# 4115138                                                   NaN
#
#                                                    Flickr URL
# Identifier
# 667         http://www.flickr.com/photos/britishlibrary/ta...
# 11852       http://www.flickr.com/photos/britishlibrary/ta...
# 55031       http://www.flickr.com/photos/britishlibrary/ta...
# 124885      http://www.flickr.com/photos/britishlibrary/ta...
# 156798      http://www.flickr.com/photos/britishlibrary/ta...
# 157633      http://www.flickr.com/photos/britishlibrary/ta...
# 259933      http://www.flickr.com/photos/britishlibrary/ta...
# 284576      http://www.flickr.com/photos/britishlibrary/ta...
# 355309      http://www.flickr.com/photos/britishlibrary/ta...
# 367760      http://www.flickr.com/photos/britishlibrary/ta...
# 381198      http://www.flickr.com/photos/britishlibrary/ta...
# 529537      http://www.flickr.com/photos/britishlibrary/ta...
# 727848      http://www.flickr.com/photos/britishlibrary/ta...
# 804446      http://www.flickr.com/photos/britishlibrary/ta...
# 811126      http://www.flickr.com/photos/britishlibrary/ta...
# 848161      http://www.flickr.com/photos/britishlibrary/ta...
# 856091      http://www.flickr.com/photos/britishlibrary/ta...
# 907096      http://www.flickr.com/photos/britishlibrary/ta...
# 911866      http://www.flickr.com/photos/britishlibrary/ta...
# 930213      http://www.flickr.com/photos/britishlibrary/ta...
# 954240      http://www.flickr.com/photos/britishlibrary/ta...
# 959759      http://www.flickr.com/photos/britishlibrary/ta...
# 979058      http://www.flickr.com/photos/britishlibrary/ta...
# 980873      http://www.flickr.com/photos/britishlibrary/ta...
# 994020      http://www.flickr.com/photos/britishlibrary/ta...
# 1024863     http://www.flickr.com/photos/britishlibrary/ta...
# 1179671     http://www.flickr.com/photos/britishlibrary/ta...
# 1197533     http://www.flickr.com/photos/britishlibrary/ta...
# 1229458     http://www.flickr.com/photos/britishlibrary/ta...
# 1246734     http://www.flickr.com/photos/britishlibrary/ta...
# ...                                                       ...
# 3619288     http://www.flickr.com/photos/britishlibrary/ta...
# 3626183     http://www.flickr.com/photos/britishlibrary/ta...
# 3631247     http://www.flickr.com/photos/britishlibrary/ta...
# 3631248     http://www.flickr.com/photos/britishlibrary/ta...
# 3641137     http://www.flickr.com/photos/britishlibrary/ta...
# 3691484     http://www.flickr.com/photos/britishlibrary/ta...
# 3705638     http://www.flickr.com/photos/britishlibrary/ta...
# 3705707     http://www.flickr.com/photos/britishlibrary/ta...
# 3761232     http://www.flickr.com/photos/britishlibrary/ta...
# 3763128     http://www.flickr.com/photos/britishlibrary/ta...
# 3775658     http://www.flickr.com/photos/britishlibrary/ta...
# 3779191     http://www.flickr.com/photos/britishlibrary/ta...
# 3806535     http://www.flickr.com/photos/britishlibrary/ta...
# 3813751     http://www.flickr.com/photos/britishlibrary/ta...
# 3865542     http://www.flickr.com/photos/britishlibrary/ta...
# 3893909     http://www.flickr.com/photos/britishlibrary/ta...
# 3926780     http://www.flickr.com/photos/britishlibrary/ta...
# 3952291     http://www.flickr.com/photos/britishlibrary/ta...
# 3993182     http://www.flickr.com/photos/britishlibrary/ta...
# 3995356     http://www.flickr.com/photos/britishlibrary/ta...
# 4018987     http://www.flickr.com/photos/britishlibrary/ta...
# 4024911     http://www.flickr.com/photos/britishlibrary/ta...
# 4046468     http://www.flickr.com/photos/britishlibrary/ta...
# 4053464     http://www.flickr.com/photos/britishlibrary/ta...
# 4072044     http://www.flickr.com/photos/britishlibrary/ta...
# 4077038     http://www.flickr.com/photos/britishlibrary/ta...
# 4112297     http://www.flickr.com/photos/britishlibrary/ta...
# 4113816     http://www.flickr.com/photos/britishlibrary/ta...
# 4114334     http://www.flickr.com/photos/britishlibrary/ta...
# 4115138     http://www.flickr.com/photos/britishlibrary/ta...
#
# [181 rows x 6 columns]

# %%
#Creating temporary dataframes for data cleaning of Date of Publication Column
df1=df0.copy()
df2=df0.copy()

# %% [markdown]
# The regex:
#
# (?<!\d) - specifies that anything before a set of 4 digits is something that is not a digit;
# (\d{4}) - matches 4 digits;
# (?!\d) - specifies that anything after a set of 4 digits is something that is not a digit

# %%
#Extracts Date of Publication from Place of Publication Column using regex
df1['Date of Publication']=df0.where(df1['Date of Publication'].isnull(),df1['Place of Publication'].str.extract(r'(?<!\d)(\d{4})(?!\d)'),axis=0)

# %%
#All but 2 null values are filled with correct data from Place of Publication column
df2['Date of Publication']=df1.where(df2['Date of Publication'].isnull(),df2['Date of Publication'],axis=0)

# %%
#Removes any extra characters taking into account only the first date in case of multiple dates 
df2['Date of Publication']=df2['Date of Publication'].str.extract(r'(?<!\d)(\d{4})(?!\d)')

# %%
#Checking for numeric data type
is_numeric_dtype(df2['Date of Publication'])
# Out:
# False

# %%
# Enforcing the Date of Publication field to Numeric value
df2['Date of Publication'] = pd.to_numeric(df2['Date of Publication'])

# %%
#Rechecking the data type of Date of Publication column
is_numeric_dtype(df2['Date of Publication'])
# Out:
# True

# %%
#Again checking for null values if any
df2['Date of Publication'].isnull().sum()
# Out:
# 2

# %%
#Tuple has no date of publication, hence it has NaN as value in df2
df0[df0.index==516336]
# Out:
#            Place of Publication        Date of Publication Publisher  \
# Identifier
# 516336                   London  112. G. & W. B. Whittaker  pp. xxvi
#
#                                                         Title  \
# Identifier
# 516336      The Italians; or, the Fatal Accusation: a trag...
#
#                      Author                                         Flickr URL
# Identifier
# 516336      BUCKE, Charles.  http://www.flickr.com/photos/britishlibrary/ta...

# %%
#Tuple has no date of publication, hence it has NaN as value in df2
df0[df0.index==3605102]
# Out:
#            Place of Publication        Date of Publication Publisher  \
# Identifier
# 3605102                  Oxford  17 vols. University Press       NaN
#
#                                                         Title  \
# Identifier
# 3605102     The Oxford Thackeray. With illustrations. [Edi...
#
#                                   Author  \
# Identifier
# 3605102     Thackeray, William Makepeace
#
#                                                    Flickr URL
# Identifier
# 3605102     http://www.flickr.com/photos/britishlibrary/ta...

# %%
#Creating Temporary Dataframe for Standardizing the Place of Publication Column
df3=df2.copy()

# %%
#Filtering out relevant cities from the Place of Publication Column and extracting City names accidently in the publisher column
Plymouth = df3['Place of Publication'].str.contains('Plymouth')
new_haven = df3['Place of Publication'].str.contains('New-Haven')
london = df3['Place of Publication'].str.contains(': London')
edinburg_london = df3['Place of Publication'].str.contains(': Edinburgh and London')
edinburg=df3['Place of Publication'].str.contains(': Edinburgh')
london1= df3['Place of Publication'].str.contains('London:')
oxford=df3['Place of Publication'].str.contains(': Oxford')
hawick=df3['Place of Publication'].str.contains(': Hawick')
barnstaple=df3['Place of Publication'].str.contains(': Barnstaple')
belfast=df3['Place of Publication'].str.contains(': Belfast')
manchester=df3['Place of Publication'].str.contains(': Manchester')
toronto=df3['Place of Publication'].str.contains('Toronto')
dublin=df3['Place of Publication'].str.contains(': Dublin')
newyork=df3['Place of Publication'].str.contains(': New York')
oldham=df3['Place of Publication'].str.contains(': Oldham')
Санктпетербургъ=df3['Place of Publication'].str.contains('Санктпетербургъ')
glasglow=df3['Place of Publication'].str.contains(': Glasgow')
paisley=df3['Place of Publication'].str.contains(': Paisley')
bodmin=df3['Place of Publication'].str.contains(': Bodmin')
hammersmith=df3['Place of Publication'].str.contains(': Hammersmith')
penzance=df3['Place of Publication'].str.contains(': Penzance')
melbourne=df3['Place of Publication'].str.contains(': Melbourne')
newport=df3['Place of Publication'].str.contains(': Newport')
leeds=df3['Place of Publication'].str.contains(': Hamblen')
copenhague=df3['Place of Publication'].str.contains('Copenhague')
montreal=df3['Place of Publication'].str.contains('Montreal')
df3['Place of Publication']=df3['Place of Publication'].str.replace('N.Y','New York')
df3['Place of Publication']=df3['Place of Publication'].str.replace('Phila\\.','Philadelphia')
df3['Place of Publication']=df3['Place of Publication'].str.replace('Saint Lo','St. Louis',regex=True)
df3['Place of Publication']=df3['Place of Publication'].str.replace('Newcastle on Tyne','Newcastle upon Tyne',regex=True)
df3['Place of Publication']=df3['Place of Publication'].str.replace('Newark, N.J','Newark')
df3['Place of Publication']=df3['Place of Publication'].str.replace('Philadelphia, Pa','Philadelphia')
df3['Place of Publication'] = df3['Place of Publication'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
df3['Place of Publication'] = df3['Place of Publication'].replace({'Orleans':'New Orleans','Boston [Mass.]':'Boston'},regex=True)
st_louis=df3['Place of Publication'].str.contains('St. Louis')
albany=df3['Place of Publication'].str.contains('Albany, New York')
auburn=df3['Place of Publication'].str.contains('Auburn, New York')
richmond=df3['Place of Publication'].str.contains('Richmond')
ny_london=df3['Place of Publication'].str.contains('Macmillan & Co')
ednbrg1=df3['Place of Publication'].str.contains('William Nimmo')
ednbrg2=df3['Place of Publication'].str.contains('William Paterson')
ednbrg3=df3['Place of Publication'].str.contains('W P Nimmo')
ednbrg_london=df3['Place of Publication'].str.contains('William Blackwood & Sons')
london11=df3['Place of Publication'].str.contains('Willoughby ')
london22=df3['Place of Publication'].str.contains('Ward & Lock')
london33=df3['Place of Publication'].str.contains('W H Allen & Co')
london44=df3['Place of Publication'].str.contains('Vernor, Hood, & Sharpe, etc')
london55=df3['Place of Publication'].str.contains('Service & Paton')
london66=df3['Place of Publication'].str.contains('sold by J. Newbery; M. Cooper')
london77=df3['Place of Publication'].str.contains('Smith, Elder & Co')
london88=df3['Place of Publication'].str.contains('Richard Bentley & Son')
london99=df3['Place of Publication'].str.contains('Remington & Co')
london111=df3['Place of Publication'].str.contains('Parker Son and Bourne')
london222=df3['Place of Publication'].str.contains('M Cooper')
london333=df3['Place of Publication'].str.contains('John ')
london444=df3['Place of Publication'].str.contains('James ')
london555=df3['Place of Publication'].str.contains('J. ')
london666=df3['Place of Publication'].str.contains('Henry G Bohn')
london777=df3['Place of Publication'].str.contains('Harrison')
london888=df3['Place of Publication'].str.contains('George Routledge & Sons')
london999=df3['Place of Publication'].str.contains('G. ')
london1111=df3['Place of Publication'].str.contains('Francis & John Rivington')
london2222=df3['Place of Publication'].str.contains('Cassell')
london3333=df3['Place of Publication'].str.contains('Bradbury & Evans')
london4444=df3['Place of Publication'].str.contains('Bliss')
london5555=df3['Place of Publication'].str.contains('Bernard Lintot')
london6666=df3['Place of Publication'].str.contains('B Law')
london7777=df3['Place of Publication'].str.contains('Bell & Daldy')
london8888=df3['Place of Publication'].str.contains('A Strahan')
london9999=df3['Place of Publication'].str.contains('A Millar')
lndn1=df3['Place of Publication'].str.contains('Bickers & Son')
madras=df3['Place of Publication'].str.contains('V Kalyanaram')
ny_b=df3['Place of Publication'].str.contains('Morse Co')
ny_l1=df3['Place of Publication'].str.contains('Macmillan & Co')
ny_l2=df3['Place of Publication'].str.contains('Alexander Strahan')
b_l=df3['Place of Publication'].str.contains('Ginn & Co')
cmb_l=df3['Place of Publication'].str.contains('Jones & Piggott')
ny_p1=df3['Place of Publication'].str.contains('Home Publishing Co')
ny_p2=df3['Place of Publication'].str.contains('Harper & Bros')
ny_p3=df3['Place of Publication'].str.contains('D. Appleton & Co')
bs1=df3['Place of Publication'].str.contains('D. C. Heath & Co')
calcutta=df3['Place of Publication'].str.contains('Baptist Mission Press')
frankfurt=df3['Place of Publication'].str.contains('Frank')
exeter=df3['Place of Publication'].str.contains('Exeter')
providence=df3['Place of Publication'].str.contains('Providence')
jamaica=df3['Place of Publication'].str.contains('Jamaica')
konigsberg=df3['Place of Publication'].str.contains('Konigsberg')
springfield=df3['Place of Publication'].str.contains('Springfield')
st_pts=df3['Place of Publication'].str.contains('St. Petersbourg')

# %%
#
df3['Place of Publication'] = np.where(Plymouth,'Plymouth',np.where(new_haven,'New Haven',np.where(edinburg_london,'Edinburgh and London',
np.where(edinburg,'Edinburgh',np.where(london, 'London',np.where(london1,'London',np.where(oxford,'Oxford',np.where(hawick,'Hawick',np.where(barnstaple,'Barnstaple',
np.where(belfast,'Belfast',np.where(manchester,'Manchester',np.where(toronto,'Toronto',np.where(dublin,'Dublin',np.where(newyork,'New York',
np.where(oldham,'oldham',np.where(Санктпетербургъ,'Санктпетербургъ',np.where(glasglow,'Glasglow',np.where(paisley,'Paisley',np.where(bodmin,'Bodmin',
np.where(hammersmith,'Hammersmith',np.where(penzance,'Penzance',np.where(melbourne,'Melbourne',np.where(newport,'Newport',
np.where(leeds,'Leeds',np.where(copenhague,'Copenhagen',np.where(montreal,'Montreal',np.where(st_louis,'St. Louis',np.where(albany,'Albany',
np.where(auburn,'Auburn',np.where(richmond,'Richmond',np.where(ny_london,'London and New York',np.where(ednbrg1,'Edinburgh',
np.where(ednbrg2,'Edinburgh',np.where(ednbrg3,'Edinburgh',np.where(ednbrg_london,'Edinburgh and London',np.where(london11,'London',np.where(london22,'London',
np.where(london33,'London',np.where(london44,'London',np.where(london55,'London',np.where(london66,'London',np.where(london77,'London',np.where(london88,'London',
np.where(london99,'London',np.where(london111,'London',np.where(london222,'London',np.where(london333,'London',np.where(london444,'London',np.where(london555,'London',
np.where(london666,'London',np.where(london777,'London',np.where(london888,'London',np.where(london999,'London',np.where(london1111,'London',np.where(london2222,'London',
np.where(london3333,'London',np.where(london4444,'London',np.where(london5555,'London',np.where(london6666,'London',np.where(london7777,'London',np.where(london8888,'London',
np.where(london9999,'London',np.where(ny_b,'New York and Boston',np.where(ny_l1,'New York and London',np.where(ny_l2,'New York and London',np.where(cmb_l,'Cambridge and London',
np.where(ny_p1,'New York',np.where(ny_p2,'New York',np.where(ny_p3,'New York',np.where(b_l,'Boston and London',np.where(bs1,'Boston',np.where(madras,'Madras',
np.where(calcutta,'Calcutta', np.where(lndn1,'London',np.where(frankfurt,'Frankfurt',np.where(exeter,'Exeter',np.where(providence,'Providence',np.where(jamaica,'Jamaica',
np.where(konigsberg,'Konigsberg',np.where(springfield,'Springfield',np.where(st_pts,'St. Petersburg', df3['Place of Publication'].str.replace('-', ' ')))))))))))))))))))))))))))
)))))))))))))))))))))))))))))))))))))))))))))))))))))))

# %%
#Using Regex to get rid of extra charachters
pattern = '|'.join(['\\[printed]', 'printed', 'reprinted','\\[U.S.]','U.S.*','Mass.*','\\[Minn.]','\\[Conn.]','\d+','\'s','\\[sic]','\\?','\\[','\\]',', Ill','pp.','; Virtue & Yorston','\\(','Printed for private circulation','Private Impression: ',
'Published in  pts','W. Frederick',' F. P. Harper',' Phillipson & Golder',' Cole Book Arcade','E. P. Dutton & Co','Aylesbury','Scribner, Welford, & Armstrong','T. Merrill','Longman & Co.','series','For Charles Harper.','pp. . D. Nutt; In the Strand','T. C. Newby','^v.','etc.: Thomas Nelson & Sons','xxxi','Privately','by B Dewhirst'])

df3['Place of Publication'] = df3['Place of Publication'].str.replace(pattern,'')

# %%
#Restructuring the data after cleaning 
df3['Place of Publication']=df3['Place of Publication'].replace('\;',',', regex=True).replace('\.','', regex=True).replace('\&',',', regex=True).replace('and',',', regex=True).replace('\:','', regex=True)

# %%
#Whitespaces cleanup
df3['Place of Publication']=df3['Place of Publication'].str.strip()

# %%
df3.to_csv('/Users/mohammadkhan/Desktop/flickr_data/std_final_df.csv')

# %%
#Deleting all the temporary dataframes 
del df1
del df2

# %%
del df3
